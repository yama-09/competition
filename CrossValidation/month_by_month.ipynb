# %% [markdown]
# # ライブラリのImport, Seedの固定

# %%
import random
import os
import torch

import numpy as np
import pandas as pd
import warnings
import pickle
from sklearn.metrics import mean_squared_error

import lightgbm as lgb
from catboost import Pool, CatBoostRegressor
import xgboost as xgb

warnings.simplefilter('ignore')

def seed_torch(seed=42):
    # python の組み込み関数の seed を固定
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    # numpy の seed を固定
    np.random.seed(seed)
    # torch の seed を固定
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # 決定論的アルゴリズムを使用する
    torch.backends.cudnn.deterministic = True

SEED = 42
seed_torch(SEED)

# %% [markdown]
# # 教師データ読み込みと前処理

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

df = pd.read_csv("~/Desktop/signate-main/data/train_add.csv") 
df_test = pd.read_csv("~/Desktop/signate-main/data/test_add.csv")


df
# Out:
#             id  year  month  day  Country  City       lat        lon  co_cnt  \
# 0            1  2019      1    1        0    24 -27.46794  153.02809      38
# 1            2  2019      1    1        0    54 -12.46113  130.84185      47
# 2            3  2019      1    1        0   146 -37.81400  144.96332      17
# 3            4  2019      1    1        0   176 -32.92953  151.78010      63
# 4            5  2019      1    1        0   193 -31.95224  115.86140      47
# ...        ...   ...    ...  ...      ...   ...       ...        ...     ...
# 195936  195937  2021     12   31       28   103  30.33218  -81.65565      12
# 195937  195938  2021     12   31       28   133  36.17497 -115.13722      14
# 195938  195939  2021     12   31       28   150  43.03890  -87.90647     171
# 195939  195940  2021     12   31       29    88  21.02450  105.84117      31
# 195940  195941  2021     12   31       29    98  20.95045  107.07336      26
#
#         co_min  ...  temperature_add  humidity_add  pressure_add   ws_add  \
# 0        0.749  ...          21.1480      246.7772      638.3688   9.6826
# 1        2.594  ...          39.8486      146.6794      612.9314  14.0216
# 2        1.190  ...          60.5012      325.0358     1517.3096  30.1830
# 3        4.586  ...          32.0948       91.2904      639.7020  11.7728
# 4        4.689  ...          18.5614      172.8750      641.8532  21.7176
# ...        ...  ...              ...           ...           ...      ...
# 195936   0.694  ...          25.3270      143.9064      620.7708   7.3574
# 195937   0.528  ...          32.3818      206.4498      624.9680  14.0382
# 195938   1.975  ...          47.4424      108.3046      654.9970  26.0542
# 195939   2.613  ...          67.8490      116.8230      678.7892  56.4306
# 195940   0.069  ...          28.5014       98.0484      632.2670   8.1810
#
#         dew_add   distance  manhattan  bearing  co_ci  near_city
# 0       12.7130  15818.210  20070.243   42.188      1         55
# 1       26.6758  14420.323  15934.564   10.566      2          1
# 2       13.4438  14489.153  20323.911   41.167      3          1
# 3       31.3184  15311.013  20538.774   45.369      4         55
# 4       22.7498  12422.947  16436.127   14.388      5          1
# ...         ...        ...        ...      ...    ...        ...
# 195936  18.1526   9207.432  12452.479  175.764    288          9
# 195937  12.0156  12237.383  16825.148 -164.519    289         17
# 195938   8.7104   9837.417  14560.461  178.571    291         10
# 195939  14.5446  11648.967  14106.819   -5.813    299         19
# 195940  13.0484  11777.047  14235.598   -6.267    301         19
#
# [195941 rows x 68 columns]

# %%
def add_yearmonth(df):
    df1 = df[df['month'] < 10].copy()
    df2 = df[df['month'] >= 10].copy()
    df1['yearmonth'] = df1['year'].astype(str) + ('0' + df1['month'].astype(str))
    df2['yearmonth'] = df2['year'].astype(str) + df2['month'].astype(str)
    return pd.concat([df1, df2])

df = add_yearmonth(df)
df_test = add_yearmonth(df_test)

df['date'] = pd.to_datetime({'year': df['year'], 'month': df['month'], 'day': df['day']})
df_test['date'] = pd.to_datetime({'year': df_test['year'], 'month': df_test['month'], 'day': df_test['day']})


df
# Out:
#             id  year  month  day  Country  City       lat        lon  co_cnt  \
# 0            1  2019      1    1        0    24 -27.46794  153.02809      38
# 1            2  2019      1    1        0    54 -12.46113  130.84185      47
# 2            3  2019      1    1        0   146 -37.81400  144.96332      17
# 3            4  2019      1    1        0   176 -32.92953  151.78010      63
# 4            5  2019      1    1        0   193 -31.95224  115.86140      47
# ...        ...   ...    ...  ...      ...   ...       ...        ...     ...
# 195936  195937  2021     12   31       28   103  30.33218  -81.65565      12
# 195937  195938  2021     12   31       28   133  36.17497 -115.13722      14
# 195938  195939  2021     12   31       28   150  43.03890  -87.90647     171
# 195939  195940  2021     12   31       29    88  21.02450  105.84117      31
# 195940  195941  2021     12   31       29    98  20.95045  107.07336      26
#
#         co_min  ...  pressure_add   ws_add  dew_add   distance  manhattan  \
# 0        0.749  ...      638.3688   9.6826  12.7130  15818.210  20070.243
# 1        2.594  ...      612.9314  14.0216  26.6758  14420.323  15934.564
# 2        1.190  ...     1517.3096  30.1830  13.4438  14489.153  20323.911
# 3        4.586  ...      639.7020  11.7728  31.3184  15311.013  20538.774
# 4        4.689  ...      641.8532  21.7176  22.7498  12422.947  16436.127
# ...        ...  ...           ...      ...      ...        ...        ...
# 195936   0.694  ...      620.7708   7.3574  18.1526   9207.432  12452.479
# 195937   0.528  ...      624.9680  14.0382  12.0156  12237.383  16825.148
# 195938   1.975  ...      654.9970  26.0542   8.7104   9837.417  14560.461
# 195939   2.613  ...      678.7892  56.4306  14.5446  11648.967  14106.819
# 195940   0.069  ...      632.2670   8.1810  13.0484  11777.047  14235.598
#
#         bearing  co_ci  near_city  yearmonth       date
# 0        42.188      1         55     201901 2019-01-01
# 1        10.566      2          1     201901 2019-01-01
# 2        41.167      3          1     201901 2019-01-01
# 3        45.369      4         55     201901 2019-01-01
# 4        14.388      5          1     201901 2019-01-01
# ...         ...    ...        ...        ...        ...
# 195936  175.764    288          9     202112 2021-12-31
# 195937 -164.519    289         17     202112 2021-12-31
# 195938  178.571    291         10     202112 2021-12-31
# 195939   -5.813    299         19     202112 2021-12-31
# 195940   -6.267    301         19     202112 2021-12-31
#
# [195941 rows x 70 columns]

# %% [markdown]
# # 学習用関数の定義

# %%
from dateutil.relativedelta import relativedelta

class TimeSeriesSplitGenerator:
    def __init__(self, n_split = 12, test_day_after = "2019-01-01", slide = False):
        self.test_day_after = pd.to_datetime(test_day_after)
        self.n_split = n_split
        self.test_month_period = 36
        self.month = relativedelta(months = 1)

        self.slide = slide

    def split(self, X):
        for m in range(self.test_month_period):
            test_month = self.test_day_after + relativedelta(months=m)
            print("test_month",test_month)
            if m == 0: # １月
                test_index = (test_month <= X.date) & (X.date < test_month + self.month)  # 2019-1-1＜X＜2019-2-1
                valid_index = ("2019-01-15 00:00:00" <= X.date) & (X.date < "2019-01-31 00:00:00") # 2019-1-1＜X＜2019-2-1
                train_index =("2019-01-01 00:00:00" <= X.date) & (X.date < "2019-01-15 00:00:00")  # 2019-1-1＜X＜2019-2-1
                if self.slide:
                    train_index = train_index &(
                        test_month - self.month - relativedelta(months =12) <= X.date
                    )
            elif m == 1: #　２月
                test_index = (test_month <= X.date) & (X.date < test_month + self.month)  # 2019-2-1＜X＜2019-3-1
                valid_index = ("2019-01-15 00:00:00" <= X.date) & (X.date < "2019-01-31 00:00:00") # 2019-1-1＜X＜2019-2-1
                train_index =("2019-01-01 00:00:00" <= X.date) & (X.date < "2019-01-15 00:00:00")  # 2019-9月よりも前
                if self.slide:
                    train_index = train_index &(
                        test_month - self.month - relativedelta(months =12) <= X.date
                    )
            else:
                test_index = (test_month <= X.date) & (X.date < test_month + self.month) # 2019-10   2019-01
                valid_index = (test_month - self.month <= X.date) & (X.date < test_month) # 2019-9
                train_index = (X.date < test_month - self.month)                          # 2019-9月よりも前
                if self.slide:
                    train_index = train_index &(
                        test_month - self.month - relativedelta(months =12) <= X.date
                    )
            yield train_index, valid_index, test_index

# %%
def lightgbm(X_train, Y_train, X_valid, Y_valid, X_test):
    bst_params = {
          "boosting_type": "gbdt",
          "metric": "rmse",
          "objective": "regression",
          "n_jobs": -1,
          "seed": SEED,
          'random_state': SEED,
          "learning_rate": 0.01,
          "bagging_fraction": 0.75,
          "bagging_freq": 10,
          "colsample_bytree": 0.75,
          "num_boost_round": 10000,
          "early_stopping_rounds": 10,
          "verbose_eval": 1000,
      }
    lgb_train = lgb.Dataset(X_train, Y_train)
    lgb_valid = lgb.Dataset(X_valid, Y_valid)

    model = lgb.train(bst_params, lgb_train,
                        valid_names=["train", "valid"], valid_sets=[lgb_train, lgb_valid],
                        verbose_eval=1000)

    # 検証データに対する予測値を求める
    va_pred = model.predict(X_valid, num_iteration=model.best_iteration)

    #テストデータに対する予測値を求める
    te_pred = np.array(model.predict(X_test, num_iteration=model.best_iteration))

    return va_pred, te_pred, model


def catboost(X_train, Y_train, X_valid, Y_valid, X_test):
    # objectの列番号を取得
    categorical_features_indices = np.where(X_train.dtypes==np.object)[0]
    lgb_train = Pool(X_train, Y_train, cat_features=categorical_features_indices)
    lgb_valid = Pool(X_valid, Y_valid, cat_features=categorical_features_indices)
    model = CatBoostRegressor(eval_metric='RMSE',
                            loss_function='RMSE',
                            num_boost_round=10000,
                            logging_level='Silent',
                            random_seed=SEED)
    model.fit(lgb_train, 
            eval_set=lgb_valid,
            early_stopping_rounds=10,
            verbose=True,
            use_best_model=True)

    # 検証データに対する予測値を求める
    va_pred = model.predict(X_valid)

    mse = mean_squared_error(Y_valid, va_pred)
    rmse = np.sqrt(mse) # RSME = √MSEの算出
    eval_metric = rmse

    print(f"eval's rmse: {eval_metric}")

    #テストデータに対する予測値を求める
    te_pred = np.array(model.predict(X_test))

    return va_pred, te_pred, model

def xgboost(X_train, Y_train, X_valid, Y_valid, X_test):

    xgb_params = {
      'objective': 'reg:linear',
      'eval_metric': 'rmse',
      # "verbosity": 0,
      "seed": SEED,
      "eta": 0.01,
      "num_boost_round": 10000,
      # "early_stopping_rounds": 10,
      # "verbose_eval": 100,
    }

    lgb_train = xgb.DMatrix(X_train, label=Y_train)
    lgb_valid = xgb.DMatrix(X_valid, label=Y_valid)
    lgb_test = xgb.DMatrix(X_test)
    evals = [(lgb_train, 'train'), (lgb_valid, 'eval')]
    evals_result = {}

    model = xgb.train(xgb_params,
                    lgb_train,
                    evals=evals,
                    evals_result=evals_result,
                    num_boost_round=10000,
                    early_stopping_rounds=10,
                    verbose_eval=1000,
                  )
  
    # 検証データに対する予測値を求める
    va_pred = model.predict(lgb_valid)

    #テストデータに対する予測値を求める
    te_pred = model.predict(lgb_test)

    return va_pred, te_pred, model

# %% [markdown]
# # 学習と予測
#
# 最初に学習済みモデル保存用にフォルダを作成しておく

# %%
main_df = df

scores = []
ids = []
submission = []

OUTPUT = "~/Desktop/sony_cup"

for i, (tr,va,te) in enumerate(TimeSeriesSplitGenerator(slide = False).split(main_df)):
    train_index, valid_index, test_index = tr,va,te

    print("-------------------------------------------")
    print("train:", main_df[train_index].date.min(), main_df[train_index].date.max())
    print("valid:", main_df[valid_index].date.min(), main_df[valid_index].date.max())

    train = main_df[train_index].dropna(subset=["pm25_mid"])
    valid = main_df[valid_index].dropna(subset=["pm25_mid"])
    
    
    if i == 0:
        year = main_df[valid_index].date.min().year
        month = main_df[valid_index].date.max().month
        test = df_test[df_test["year"] == year]
        test = test[test["month"] == month]
        print("test: ", test.date.min(), test.date.max())
        print(f'Fold : {i}')
    else:
        year = (main_df[valid_index].date.min()  + relativedelta(months=1)).year
        month = (main_df[valid_index].date.max() + relativedelta(months=1)).month
        test = df_test[df_test["year"] == year]
        test = test[test["month"] == month]
        print("test: ", test.date.min(), test.date.max())
        print(f'Fold : {i}')
    
    
    train_add = train

    X_train, Y_train = train_add.drop(columns=["pm25_mid","date","id","yearmonth"]), train_add["pm25_mid"]
    X_valid, Y_valid = valid.drop(columns=["pm25_mid","date","id","yearmonth"]), valid["pm25_mid"]
    ids += list(test["id"])
    X_test = test.drop(columns=["date","id","yearmonth"])

    print("LGBD")
    va_pred1, te_pred1, model = lightgbm(X_train, Y_train, X_valid, Y_valid, X_test)
    #pickle.dump(model, open(f"{OUTPUT}/lgbm/{start_date}.pkl", 'wb'))
    print()
    print("CABT")
    #va_pred2, te_pred2, model = catboost(X_train, Y_train, X_valid, Y_valid, X_test)
    #pickle.dump(model, open(f"{OUTPUT}/cat/{start_date}.pkl", 'wb'))
    print()
    print("XGBT")
    #va_pred3, te_pred3, model = xgboost(X_train, Y_train, X_valid, Y_valid, X_test)
    #pickle.dump(model, open(f"{OUTPUT}/xgb/{start_date}.pkl", 'wb'))

    #va_pred = (va_pred1 / 3) + (va_pred2 / 3) + (va_pred3 / 3)
    #te_pred = (te_pred1 / 3) + (te_pred2 / 3) + (te_pred3 / 3)

    va_pred = (va_pred1)
    te_pred = (te_pred1)

    # RSME = √MSEの算出
    mse = mean_squared_error(Y_valid, va_pred)
    rmse = np.sqrt(mse)

    scores.append(rmse)

    #テストデータに対する予測値を求める
    submission += list(te_pred)

    print('')
    print('################################')
    print(f"Fold: {i} RMSE:{rmse}")
    print("")

print() 
print(f"CV: {np.mean(scores)}")
print("Best CV: 21.150075570163597")

# CV: 3.4555098
# Out:
# test_month 2019-01-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-01-14 00:00:00
# valid: 2019-01-15 00:00:00 2019-01-30 00:00:00
# test:  2019-01-01 00:00:00 2019-01-31 00:00:00
# Fold : 0
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001536 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15344
# [LightGBM] [Info] Number of data points in the train set: 2485, number of used features: 64
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 74.758560
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [720]	train's rmse: 12.7066	valid's rmse: 26.82
#
# CABT
#
# XGBT
#
# ################################
# Fold: 0 RMSE:26.819999746716686
#
# test_month 2019-02-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-01-14 00:00:00
# valid: 2019-01-15 00:00:00 2019-01-30 00:00:00
# test:  2019-02-01 00:00:00 2019-02-28 00:00:00
# Fold : 1
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15344
# [LightGBM] [Info] Number of data points in the train set: 2485, number of used features: 64
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 74.758560
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [720]	train's rmse: 12.7066	valid's rmse: 26.82
#
# CABT
#
# XGBT
#
# ################################
# Fold: 1 RMSE:26.819999746716686
#
# test_month 2019-03-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-01-31 00:00:00
# valid: 2019-02-01 00:00:00 2019-02-28 00:00:00
# test:  2019-03-01 00:00:00 2019-03-31 00:00:00
# Fold : 2
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15402
# [LightGBM] [Info] Number of data points in the train set: 5494, number of used features: 64
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 72.650419
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [614]	train's rmse: 17.6622	valid's rmse: 26.8225
#
# CABT
#
# XGBT
#
# ################################
# Fold: 2 RMSE:26.822464407742046
#
# test_month 2019-04-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-02-28 00:00:00
# valid: 2019-03-01 00:00:00 2019-03-31 00:00:00
# test:  2019-04-01 00:00:00 2019-04-30 00:00:00
# Fold : 3
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15458
# [LightGBM] [Info] Number of data points in the train set: 10091, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 72.528849
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [810]	train's rmse: 18.6698	valid's rmse: 24.133
#
# CABT
#
# XGBT
#
# ################################
# Fold: 3 RMSE:24.13300136244347
#
# test_month 2019-05-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-03-31 00:00:00
# valid: 2019-04-01 00:00:00 2019-04-30 00:00:00
# test:  2019-05-01 00:00:00 2019-05-31 00:00:00
# Fold : 4
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002963 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15503
# [LightGBM] [Info] Number of data points in the train set: 16497, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 68.496871
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [851]	train's rmse: 19.6967	valid's rmse: 21.3132
#
# CABT
#
# XGBT
#
# ################################
# Fold: 4 RMSE:21.31315239304844
#
# test_month 2019-06-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-04-30 00:00:00
# valid: 2019-05-01 00:00:00 2019-05-31 00:00:00
# test:  2019-06-01 00:00:00 2019-06-30 00:00:00
# Fold : 5
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15523
# [LightGBM] [Info] Number of data points in the train set: 22347, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 65.818224
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.1737	valid's rmse: 19.3342
# Early stopping, best iteration is:
# [1079]	train's rmse: 18.9026	valid's rmse: 19.2977
#
# CABT
#
# XGBT
#
# ################################
# Fold: 5 RMSE:19.29765137494789
#
# test_month 2019-07-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-05-31 00:00:00
# valid: 2019-06-01 00:00:00 2019-06-30 00:00:00
# test:  2019-07-01 00:00:00 2019-07-31 00:00:00
# Fold : 6
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15532
# [LightGBM] [Info] Number of data points in the train set: 28482, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 62.777100
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.0089	valid's rmse: 19.7349
# Early stopping, best iteration is:
# [1021]	train's rmse: 18.943	valid's rmse: 19.7251
#
# CABT
#
# XGBT
#
# ################################
# Fold: 6 RMSE:19.725066198811447
#
# test_month 2019-08-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-06-30 00:00:00
# valid: 2019-07-01 00:00:00 2019-07-31 00:00:00
# test:  2019-08-01 00:00:00 2019-08-31 00:00:00
# Fold : 7
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003644 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15541
# [LightGBM] [Info] Number of data points in the train set: 34622, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.659067
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [921]	train's rmse: 19.1142	valid's rmse: 18.5205
#
# CABT
#
# XGBT
#
# ################################
# Fold: 7 RMSE:18.520485470077325
#
# test_month 2019-09-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-07-31 00:00:00
# valid: 2019-08-01 00:00:00 2019-08-31 00:00:00
# test:  2019-09-01 00:00:00 2019-09-30 00:00:00
# Fold : 8
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005511 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15554
# [LightGBM] [Info] Number of data points in the train set: 40853, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.815087
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 18.657	valid's rmse: 17.826
# Early stopping, best iteration is:
# [1051]	train's rmse: 18.533	valid's rmse: 17.8134
#
# CABT
#
# XGBT
#
# ################################
# Fold: 8 RMSE:17.813448517778976
#
# test_month 2019-10-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-08-31 00:00:00
# valid: 2019-09-01 00:00:00 2019-09-30 00:00:00
# test:  2019-10-01 00:00:00 2019-10-31 00:00:00
# Fold : 9
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15555
# [LightGBM] [Info] Number of data points in the train set: 46624, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.606268
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 18.4979	valid's rmse: 18.5399
# Early stopping, best iteration is:
# [1550]	train's rmse: 17.434	valid's rmse: 18.3513
#
# CABT
#
# XGBT
#
# ################################
# Fold: 9 RMSE:18.35127965619333
#
# test_month 2019-11-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-09-30 00:00:00
# valid: 2019-10-01 00:00:00 2019-10-31 00:00:00
# test:  2019-11-01 00:00:00 2019-11-30 00:00:00
# Fold : 10
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005001 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15563
# [LightGBM] [Info] Number of data points in the train set: 51933, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.123848
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [947]	train's rmse: 18.571	valid's rmse: 23.836
#
# CABT
#
# XGBT
#
# ################################
# Fold: 10 RMSE:23.836018902175308
#
# test_month 2019-12-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-10-31 00:00:00
# valid: 2019-11-01 00:00:00 2019-11-30 00:00:00
# test:  2019-12-01 00:00:00 2019-12-31 00:00:00
# Fold : 11
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005649 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15563
# [LightGBM] [Info] Number of data points in the train set: 57928, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.690480
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 18.7768	valid's rmse: 22.535
# Early stopping, best iteration is:
# [1339]	train's rmse: 18.1619	valid's rmse: 22.2625
#
# CABT
#
# XGBT
#
# ################################
# Fold: 11 RMSE:22.262501876015243
#
# test_month 2020-01-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-11-30 00:00:00
# valid: 2019-12-01 00:00:00 2019-12-31 00:00:00
# test:  2020-01-01 00:00:00 2020-01-31 00:00:00
# Fold : 12
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15564
# [LightGBM] [Info] Number of data points in the train set: 63468, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.176407
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 18.9602	valid's rmse: 25.6017
# Early stopping, best iteration is:
# [1422]	train's rmse: 18.2257	valid's rmse: 25.2266
#
# CABT
#
# XGBT
#
# ################################
# Fold: 12 RMSE:25.22655910593016
#
# test_month 2020-02-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2019-12-31 00:00:00
# valid: 2020-01-01 00:00:00 2020-01-31 00:00:00
# test:  2020-02-01 00:00:00 2020-02-28 00:00:00
# Fold : 13
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006855 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15565
# [LightGBM] [Info] Number of data points in the train set: 69365, number of used features: 65
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.157891
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.39	valid's rmse: 28.2139
# Early stopping, best iteration is:
# [1118]	train's rmse: 19.1677	valid's rmse: 28.1387
#
# CABT
#
# XGBT
#
# ################################
# Fold: 13 RMSE:28.138661497487607
#
# test_month 2020-03-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-01-31 00:00:00
# valid: 2020-02-01 00:00:00 2020-02-28 00:00:00
# test:  2020-03-01 00:00:00 2020-03-31 00:00:00
# Fold : 14
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15568
# [LightGBM] [Info] Number of data points in the train set: 72661, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.216979
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [861]	train's rmse: 20.106	valid's rmse: 25.8293
#
# CABT
#
# XGBT
#
# ################################
# Fold: 14 RMSE:25.829335883388048
#
# test_month 2020-04-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-02-28 00:00:00
# valid: 2020-03-01 00:00:00 2020-03-31 00:00:00
# test:  2020-04-01 00:00:00 2020-04-30 00:00:00
# Fold : 15
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15568
# [LightGBM] [Info] Number of data points in the train set: 74824, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.376446
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.9826	valid's rmse: 24.9778
# Early stopping, best iteration is:
# [1107]	train's rmse: 19.788	valid's rmse: 24.942
#
# CABT
#
# XGBT
#
# ################################
# Fold: 15 RMSE:24.942033346241697
#
# test_month 2020-05-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-03-31 00:00:00
# valid: 2020-04-01 00:00:00 2020-04-30 00:00:00
# test:  2020-05-01 00:00:00 2020-05-31 00:00:00
# Fold : 16
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008104 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15567
# [LightGBM] [Info] Number of data points in the train set: 81223, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.836085
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.395	valid's rmse: 20.1241
# Early stopping, best iteration is:
# [1021]	train's rmse: 20.3543	valid's rmse: 20.1062
#
# CABT
#
# XGBT
#
# ################################
# Fold: 16 RMSE:20.10622339091879
#
# test_month 2020-06-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-04-30 00:00:00
# valid: 2020-05-01 00:00:00 2020-05-31 00:00:00
# test:  2020-06-01 00:00:00 2020-06-30 00:00:00
# Fold : 17
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15567
# [LightGBM] [Info] Number of data points in the train set: 86729, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.876939
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.3136	valid's rmse: 17.8241
# Early stopping, best iteration is:
# [1153]	train's rmse: 20.057	valid's rmse: 17.7427
#
# CABT
#
# XGBT
#
# ################################
# Fold: 17 RMSE:17.742675372304568
#
# test_month 2020-07-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-05-31 00:00:00
# valid: 2020-06-01 00:00:00 2020-06-30 00:00:00
# test:  2020-07-01 00:00:00 2020-07-31 00:00:00
# Fold : 18
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008635 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15567
# [LightGBM] [Info] Number of data points in the train set: 92592, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.352229
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [861]	train's rmse: 20.4189	valid's rmse: 17.1232
#
# CABT
#
# XGBT
#
# ################################
# Fold: 18 RMSE:17.123245834901027
#
# test_month 2020-08-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-06-30 00:00:00
# valid: 2020-07-01 00:00:00 2020-07-31 00:00:00
# test:  2020-08-01 00:00:00 2020-08-31 00:00:00
# Fold : 19
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15567
# [LightGBM] [Info] Number of data points in the train set: 98034, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.758909
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.9805	valid's rmse: 15.9227
# Early stopping, best iteration is:
# [1670]	train's rmse: 19.0741	valid's rmse: 15.6499
#
# CABT
#
# XGBT
#
# ################################
# Fold: 19 RMSE:15.64989802814202
#
# test_month 2020-09-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-07-31 00:00:00
# valid: 2020-08-01 00:00:00 2020-08-31 00:00:00
# test:  2020-09-01 00:00:00 2020-09-30 00:00:00
# Fold : 20
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15566
# [LightGBM] [Info] Number of data points in the train set: 103923, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.068869
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.7594	valid's rmse: 17.0727
# Early stopping, best iteration is:
# [1013]	train's rmse: 19.7368	valid's rmse: 17.0627
#
# CABT
#
# XGBT
#
# ################################
# Fold: 20 RMSE:17.0627240275786
#
# test_month 2020-10-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-08-31 00:00:00
# valid: 2020-09-01 00:00:00 2020-09-30 00:00:00
# test:  2020-10-01 00:00:00 2020-10-31 00:00:00
# Fold : 21
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010551 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15566
# [LightGBM] [Info] Number of data points in the train set: 109831, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.536676
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.6115	valid's rmse: 17.9654
# Early stopping, best iteration is:
# [1420]	train's rmse: 19.0255	valid's rmse: 17.7812
#
# CABT
#
# XGBT
#
# ################################
# Fold: 21 RMSE:17.781184370189667
#
# test_month 2020-11-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-09-30 00:00:00
# valid: 2020-10-01 00:00:00 2020-10-31 00:00:00
# test:  2020-11-01 00:00:00 2020-11-30 00:00:00
# Fold : 22
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011048 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15573
# [LightGBM] [Info] Number of data points in the train set: 115445, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.293974
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.5119	valid's rmse: 20.0437
# Early stopping, best iteration is:
# [1279]	train's rmse: 19.1214	valid's rmse: 19.8689
#
# CABT
#
# XGBT
#
# ################################
# Fold: 22 RMSE:19.868936216983865
#
# test_month 2020-12-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-10-31 00:00:00
# valid: 2020-11-01 00:00:00 2020-11-30 00:00:00
# test:  2020-12-01 00:00:00 2020-12-31 00:00:00
# Fold : 23
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011097 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15573
# [LightGBM] [Info] Number of data points in the train set: 121427, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 57.478220
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.5025	valid's rmse: 23.224
# Early stopping, best iteration is:
# [1739]	train's rmse: 18.6226	valid's rmse: 22.694
#
# CABT
#
# XGBT
#
# ################################
# Fold: 23 RMSE:22.69400021480082
#
# test_month 2021-01-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-11-30 00:00:00
# valid: 2020-12-01 00:00:00 2020-12-31 00:00:00
# test:  2021-01-01 00:00:00 2021-01-31 00:00:00
# Fold : 24
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011375 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15572
# [LightGBM] [Info] Number of data points in the train set: 126780, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.006826
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.6175	valid's rmse: 24.3275
# Early stopping, best iteration is:
# [1713]	train's rmse: 18.762	valid's rmse: 23.7891
#
# CABT
#
# XGBT
#
# ################################
# Fold: 24 RMSE:23.78911314087214
#
# test_month 2021-02-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2020-12-31 00:00:00
# valid: 2021-01-01 00:00:00 2021-01-31 00:00:00
# test:  2021-02-01 00:00:00 2021-02-28 00:00:00
# Fold : 25
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15571
# [LightGBM] [Info] Number of data points in the train set: 132358, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.752380
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.7797	valid's rmse: 26.0446
# Early stopping, best iteration is:
# [1080]	train's rmse: 19.6591	valid's rmse: 25.941
#
# CABT
#
# XGBT
#
# ################################
# Fold: 25 RMSE:25.941005351527338
#
# test_month 2021-03-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-01-31 00:00:00
# valid: 2021-02-01 00:00:00 2021-02-28 00:00:00
# test:  2021-03-01 00:00:00 2021-03-31 00:00:00
# Fold : 26
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012986 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15572
# [LightGBM] [Info] Number of data points in the train set: 137660, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.553830
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.9493	valid's rmse: 23.9959
# Early stopping, best iteration is:
# [1211]	train's rmse: 19.6466	valid's rmse: 23.8441
#
# CABT
#
# XGBT
#
# ################################
# Fold: 26 RMSE:23.84412515288214
#
# test_month 2021-04-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-02-28 00:00:00
# valid: 2021-03-01 00:00:00 2021-03-31 00:00:00
# test:  2021-04-01 00:00:00 2021-04-30 00:00:00
# Fold : 27
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.012698 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15571
# [LightGBM] [Info] Number of data points in the train set: 142317, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.080137
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.0462	valid's rmse: 24.7172
# Early stopping, best iteration is:
# [1942]	train's rmse: 18.9871	valid's rmse: 24.3659
#
# CABT
#
# XGBT
#
# ################################
# Fold: 27 RMSE:24.365945342901867
#
# test_month 2021-05-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-03-31 00:00:00
# valid: 2021-04-01 00:00:00 2021-04-30 00:00:00
# test:  2021-05-01 00:00:00 2021-05-31 00:00:00
# Fold : 28
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15571
# [LightGBM] [Info] Number of data points in the train set: 148964, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.222738
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.2503	valid's rmse: 18.8222
# Early stopping, best iteration is:
# [1113]	train's rmse: 20.0835	valid's rmse: 18.774
#
# CABT
#
# XGBT
#
# ################################
# Fold: 28 RMSE:18.773955651900085
#
# test_month 2021-06-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-04-30 00:00:00
# valid: 2021-05-01 00:00:00 2021-05-31 00:00:00
# test:  2021-06-01 00:00:00 2021-06-30 00:00:00
# Fold : 29
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.013677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 154298, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 60.261895
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [812]	train's rmse: 20.5324	valid's rmse: 18.5555
#
# CABT
#
# XGBT
#
# ################################
# Fold: 29 RMSE:18.555470761313945
#
# test_month 2021-07-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-05-31 00:00:00
# valid: 2021-06-01 00:00:00 2021-06-30 00:00:00
# test:  2021-07-01 00:00:00 2021-07-31 00:00:00
# Fold : 30
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 160133, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.911466
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.1374	valid's rmse: 16.7052
# Early stopping, best iteration is:
# [1451]	train's rmse: 19.5801	valid's rmse: 16.4337
#
# CABT
#
# XGBT
#
# ################################
# Fold: 30 RMSE:16.43366539217784
#
# test_month 2021-08-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-06-30 00:00:00
# valid: 2021-07-01 00:00:00 2021-07-31 00:00:00
# test:  2021-08-01 00:00:00 2021-08-31 00:00:00
# Fold : 31
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.014739 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 165412, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.606029
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 20.0307	valid's rmse: 16.303
# Early stopping, best iteration is:
# [1415]	train's rmse: 19.5091	valid's rmse: 16.0268
#
# CABT
#
# XGBT
#
# ################################
# Fold: 31 RMSE:16.02676840763315
#
# test_month 2021-09-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-07-31 00:00:00
# valid: 2021-08-01 00:00:00 2021-08-31 00:00:00
# test:  2021-09-01 00:00:00 2021-09-30 00:00:00
# Fold : 32
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015227 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 170912, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 59.232013
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.9144	valid's rmse: 16.3717
# Early stopping, best iteration is:
# [1914]	train's rmse: 18.9524	valid's rmse: 16.0333
#
# CABT
#
# XGBT
#
# ################################
# Fold: 32 RMSE:16.033312993801125
#
# test_month 2021-10-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-08-31 00:00:00
# valid: 2021-09-01 00:00:00 2021-09-30 00:00:00
# test:  2021-10-01 00:00:00 2021-10-31 00:00:00
# Fold : 33
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.015552 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 176177, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.905488
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [411]	train's rmse: 21.3524	valid's rmse: 16.9715
#
# CABT
#
# XGBT
#
# ################################
# Fold: 33 RMSE:16.971476413592473
#
# test_month 2021-11-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-09-30 00:00:00
# valid: 2021-10-01 00:00:00 2021-10-31 00:00:00
# test:  2021-11-01 00:00:00 2021-11-30 00:00:00
# Fold : 34
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 181388, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.637564
# Training until validation scores don't improve for 10 rounds
# [1000]	train's rmse: 19.7196	valid's rmse: 19.2163
# Early stopping, best iteration is:
# [1483]	train's rmse: 19.1579	valid's rmse: 19.0518
#
# CABT
#
# XGBT
#
# ################################
# Fold: 34 RMSE:19.051828875961956
#
# test_month 2021-12-01 00:00:00
# -------------------------------------------
# train: 2019-01-01 00:00:00 2021-10-31 00:00:00
# valid: 2021-11-01 00:00:00 2021-11-30 00:00:00
# test:  2021-12-01 00:00:00 2021-12-31 00:00:00
# Fold : 35
# LGBD
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15578
# [LightGBM] [Info] Number of data points in the train set: 185713, number of used features: 66
# [LightGBM] [Warning] Unknown parameter: verbose_eval
# [LightGBM] [Warning] seed is set=42, random_state=42 will be ignored. Current value: seed=42
# [LightGBM] [Info] Start training from score 58.583085
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [813]	train's rmse: 19.9999	valid's rmse: 23.7355
#
# CABT
#
# XGBT
#
# ################################
# Fold: 35 RMSE:23.735506099791802
#
#
# CV: 21.150075570163597
# Best CV: 21.150075570163597

# %%
sub = pd.Series(submission)
sub.index = ids
sub.to_csv(f"{OUTPUT}/submmission_ensenble(month_by_month).csv",header=False)
sub
# Out:
# 195942     11.706840
# 195943     39.613038
# 195944     31.287131
# 195945     61.769683
# 195946    134.242223
#              ...
# 249446     72.697392
# 249447    124.563946
# 249448     68.295455
# 249449     35.044842
# 249450     39.084504
# Length: 53509, dtype: float64

# %%
from tqdm import tqdm
all_data = pd.read_csv("~/Desktop/signate-main/submit_ensamble_safety.csv",header=None)
mon_data = pd.read_csv("~/Desktop/sony_cup/submmission_ensenble(month_by_month).csv",header=None)


for i in tqdm(range(2693)):
    mon_data[1][i] = all_data[1][i] 

mon_data.to_csv('~/Desktop/submit_month.csv', header=False, index=False)
mon_data
# Out:
# 100%|██████████| 2693/2693 [00:00<00:00, 6122.80it/s]
#             0           1
# 0      195942   22.206779
# 1      195943   38.103874
# 2      195944   27.759193
# 3      195945   66.442556
# 4      195946  135.993679
# ...       ...         ...
# 53504  249446   72.697392
# 53505  249447  124.563946
# 53506  249448   68.295455
# 53507  249449   35.044842
# 53508  249450   39.084504
#
# [53509 rows x 2 columns]
